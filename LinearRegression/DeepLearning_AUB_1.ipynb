# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/multiple_linear_regression_data.csv')
print("dataset Head:\n", df.head())
# Out:
# dataset Head:
#     Advertising_TV  Advertising_Radio  Advertising_Newspaper  Sales
# 0           230.1               37.8                   69.2   22.1
# 1            44.5               39.3                   45.1   10.4
# 2            17.2               45.9                   69.3    9.3
# 3           151.5               41.3                   58.5   18.5
# 4           180.8               10.8                   58.4   12.9

# %%
x = df[['Advertising_TV', 'Advertising_Radio', 'Advertising_Newspaper']]
y = df['Sales']

# %%
x_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
mlr_model = LinearRegression()
mlr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = mlr_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 13.201451790963423
# R-squared: -0.6838586468065588

# %%
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linewidth=2)
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title('multiple linear regression: Actual vs predicted')
plt.show()
